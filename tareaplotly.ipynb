# %% [markdown]
# # **Llamar librerias**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import seaborn as sns ##Graficos bien hechos, bonitos
import warnings
import  plotly.express  as  px
warnings.filterwarnings("ignore", category=FutureWarning)

print("Setup Complete")
# Out:
# Setup Complete

# %%
from google.colab import files 
uploaded= files.upload ()
# Out:
#      <input type="file" id="files-d4d0c766-709d-4c96-b17c-b8ee9768f943" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d4d0c766-709d-4c96-b17c-b8ee9768f943">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Accelerometer.txt to Accelerometer (1).txt

# %%
data=pd.read_csv("Accelerometer.txt",delimiter=",",skiprows=2)
data.head(5)
# Out:
#    Time (s)   X (m/s2)   Y (m/s2)   Z (m/s2)   R (m/s2)   Theta (deg)  \
# 0  0.000000   0.214526   0.948162   0.330820   1.026876     71.206337
# 1  0.016852   0.244057   0.979280   0.300801   1.053107     73.403389
# 2  0.026836   0.216235   0.928638   0.323986   1.007022     71.232605
# 3  0.036989   0.165715   0.873603   0.341070   0.952351     69.014305
# 4  0.046939   0.137526   0.866769   0.335701   0.939626     69.067337
#
#     Phi (deg)
# 0   77.251205
# 1   76.005760
# 2   76.892159
# 3   79.259102
# 4   80.984299

# %%
fig = px.line(data, x="Time (s)", y=data.columns[4:5], title='Resultante')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig.write_html("baloncesto.html")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig1 = px.line(data, x="Time (s)", y=data.columns[1:4], title='XYZ')
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
